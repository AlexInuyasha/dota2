# %%
import requests
import pandas as pd

Opendota_api_heros_url = "https://api.opendota.com/api/heroes"
print(Opendota_api_heros_url)
r = requests.get(Opendota_api_heros_url, timeout=3)
r_json = r.json()
en_hero_df = pd.DataFrame(r_json)
en_hero_df.head(3)
# Out:
# https://api.opendota.com/api/heroes
#    id                    name localized_name primary_attr attack_type  \
# 0   1  npc_dota_hero_antimage      Anti-Mage          agi       Melee
# 1   2       npc_dota_hero_axe            Axe          str       Melee
# 2   3      npc_dota_hero_bane           Bane          int      Ranged
#
#                                             roles  legs
# 0                          [Carry, Escape, Nuker]     2
# 1  [Initiator, Durable, Disabler, Jungler, Carry]     2
# 2             [Support, Disabler, Nuker, Durable]     4

# %%
en_hero_df=en_hero_df.rename(columns={"localized_name": "en_official_name", "id": "hero_id", "name": "ingame_name"})

Steam_key = '15CC480338F0DD1DB2E875618D8072F2'
Valve_api_get_heros_url = f"https://api.steampowered.com/IEconDOTA2_570/GetHeroes/v0001/?key={Steam_key}&language=zh-cn"

r = requests.get(Valve_api_get_heros_url, timeout=3)
r_json = r.json()
cn_hero_df = pd.DataFrame(r_json["result"]["heroes"])

hero_df = pd.merge(cn_hero_df.rename(columns = {'name':'ingame_name','localized_name':'hero_name'}),en_hero_df,on='ingame_name')
hero_df.head(3)
# Out:
#               ingame_name  id hero_name  hero_id en_official_name  \
# 0  npc_dota_hero_antimage   1       敌法师        1        Anti-Mage
# 1       npc_dota_hero_axe   2        斧王        2              Axe
# 2      npc_dota_hero_bane   3      祸乱之源        3             Bane
#
#   primary_attr attack_type                                           roles  \
# 0          agi       Melee                          [Carry, Escape, Nuker]
# 1          str       Melee  [Initiator, Durable, Disabler, Jungler, Carry]
# 2          int      Ranged             [Support, Disabler, Nuker, Durable]
#
#    legs
# 0     2
# 1     2
# 2     4

# %%
df2 = hero_df.loc[:,['hero_id', 'ingame_name', 'en_official_name', 'primary_attr',
               'attack_type', 'legs', 'hero_name']]
df2.head(3)
# Out:
#    hero_id             ingame_name en_official_name primary_attr attack_type  \
# 0        1  npc_dota_hero_antimage        Anti-Mage          agi       Melee
# 1        2       npc_dota_hero_axe              Axe          str       Melee
# 2        3      npc_dota_hero_bane             Bane          int      Ranged
#
#    legs hero_name
# 0     2       敌法师
# 1     2        斧王
# 2     4      祸乱之源

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String
import pymysql

Base = declarative_base()
engine = create_engine('mysql+pymysql://root:12345678@47.108.75.36:3306/dbname', echo=True)

class SysHero(Base):
    # 指定映射表名
    __tablename__ = 'hero'

    # id 设置为主键
    hero_id = Column(Integer, primary_key=True)
    # 指定 name 映射到 name 字段
    ingame_name = Column(String(30))
    en_official_name = Column(String(32))
    primary_attr = Column(String(32))
    attack_type = Column(String(32))
    legs = Column(Integer)
    hero_name = Column(String(32))
    

# hero_df = hero_df.drop(columns=['roles'])
hero_df.head(1)
hero_df.head(1).to_sql("hero", con=engine, if_exists="append", index=False)

# def converse(list):
#     str = ""
#     for x in list:
#         str.join(x)

#     return str
# Out:
# 2021-10-23 00:38:42,754 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2021-10-23 00:38:42,755 INFO sqlalchemy.engine.base.Engine {}
# 2021-10-23 00:38:42,762 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2021-10-23 00:38:42,762 INFO sqlalchemy.engine.base.Engine {}
# 2021-10-23 00:38:42,773 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2021-10-23 00:38:42,774 INFO sqlalchemy.engine.base.Engine {}
# 2021-10-23 00:38:42,783 INFO sqlalchemy.engine.base.Engine show collation where `Charset` = 'utf8mb4' and `Collation` = 'utf8mb4_bin'
# 2021-10-23 00:38:42,784 INFO sqlalchemy.engine.base.Engine {}
# 2021-10-23 00:38:42,790 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2021-10-23 00:38:42,790 INFO sqlalchemy.engine.base.Engine {}
# 2021-10-23 00:38:42,795 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# 2021-10-23 00:38:42,796 INFO sqlalchemy.engine.base.Engine {}
# 2021-10-23 00:38:42,801 INFO sqlalchemy.engine.base.Engine SELECT CAST('test collated returns' AS CHAR CHARACTER SET utf8mb4) COLLATE utf8mb4_bin AS anon_1
# 2021-10-23 00:38:42,801 INFO sqlalchemy.engine.base.Engine {}
# 2021-10-23 00:38:42,815 INFO sqlalchemy.engine.base.Engine DESCRIBE `hero`
# 2021-10-23 00:38:42,815 INFO sqlalchemy.engine.base.Engine {}
# 2021-10-23 00:38:42,826 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-10-23 00:38:42,827 INFO sqlalchemy.engine.base.Engine INSERT INTO hero (ingame_name, id, hero_name, hero_id, en_official_name, primary_attr, attack_type, legs) VALUES (%(ingame_name)s, %(id)s, %(hero_name)s, %(hero_id)s, %(en_official_name)s, %(primary_attr)s, %(attack_type)s, %(legs)s)
# 2021-10-23 00:38:42,827 INFO sqlalchemy.engine.base.Engine {'ingame_name': 'npc_dota_hero_antimage', 'id': 1, 'hero_name': '敌法师', 'hero_id': 1, 'en_official_name': 'Anti-Mage', 'primary_attr': 'agi', 'attack_type': 'Melee', 'legs': 2}
# 2021-10-23 00:38:42,832 INFO sqlalchemy.engine.base.Engine ROLLBACK
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# E:\soft\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#
# E:\soft\anaconda\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# E:\soft\anaconda\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# E:\soft\anaconda\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#
# E:\soft\anaconda\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#
# E:\soft\anaconda\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#
# E:\soft\anaconda\lib\site-packages\pymysql\connections.py in read(self)
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#
# E:\soft\anaconda\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#
# E:\soft\anaconda\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# E:\soft\anaconda\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# DataError: (1366, "Incorrect string value: '\\xE6\\x95\\x8C\\xE6\\xB3\\x95...' for column 'hero_name' at row 1")
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# <ipython-input-18-84ea42d985bf> in <module>
#      25 # hero_df = hero_df.drop(columns=['roles'])
#      26 hero_df.head(1)
# ---> 27 hero_df.head(1).to_sql("hero", con=engine, if_exists="append", index=False)
#      28
#      29 # def converse(list):
#
# E:\soft\anaconda\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# E:\soft\anaconda\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# E:\soft\anaconda\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# E:\soft\anaconda\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# E:\soft\anaconda\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# E:\soft\anaconda\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# E:\soft\anaconda\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# E:\soft\anaconda\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# E:\soft\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# E:\soft\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# E:\soft\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# E:\soft\anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# E:\soft\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1274                             break
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#    1278                     )
#
# E:\soft\anaconda\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# E:\soft\anaconda\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# E:\soft\anaconda\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# E:\soft\anaconda\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# E:\soft\anaconda\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# E:\soft\anaconda\lib\site-packages\pymysql\connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# E:\soft\anaconda\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# E:\soft\anaconda\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# E:\soft\anaconda\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# DataError: (pymysql.err.DataError) (1366, "Incorrect string value: '\\xE6\\x95\\x8C\\xE6\\xB3\\x95...' for column 'hero_name' at row 1")
# [SQL: INSERT INTO hero (ingame_name, id, hero_name, hero_id, en_official_name, primary_attr, attack_type, legs) VALUES (%(ingame_name)s, %(id)s, %(hero_name)s, %(hero_id)s, %(en_official_name)s, %(primary_attr)s, %(attack_type)s, %(legs)s)]
# [parameters: {'ingame_name': 'npc_dota_hero_antimage', 'id': 1, 'hero_name': '敌法师', 'hero_id': 1, 'en_official_name': 'Anti-Mage', 'primary_attr': 'agi', 'attack_type': 'Melee', 'legs': 2}]
# (Background on this error at: http://sqlalche.me/e/13/9h9h)

# %%
# pip install jupyter_contrib_nbextensions && jupyter contrib nbextension install

# %%
pip install jupyterLab-git
# Out:
# Collecting jupyterLab-git
#   Using cached jupyterlab_git-0.33.0-py3-none-any.whl (517 kB)
# Collecting jupyter-server
#   Using cached jupyter_server-1.11.1-py3-none-any.whl (393 kB)
# Collecting nbdime~=3.1
#   Using cached nbdime-3.1.1-py2.py3-none-any.whl (5.3 MB)
# Requirement already satisfied: pexpect in e:\soft\anaconda\lib\site-packages (from jupyterLab-git) (4.8.0)
# Requirement already satisfied: nbformat in e:\soft\anaconda\lib\site-packages (from jupyterLab-git) (5.0.8)
# Requirement already satisfied: packaging in e:\soft\anaconda\lib\site-packages (from jupyterLab-git) (20.4)
# Requirement already satisfied: jupyter-core>=4.6.0 in e:\soft\anaconda\lib\site-packages (from jupyter-server->jupyterLab-git) (4.6.3)
# Requirement already satisfied: nbconvert in e:\soft\anaconda\lib\site-packages (from jupyter-server->jupyterLab-git) (6.0.7)
# Requirement already satisfied: Send2Trash in e:\soft\anaconda\lib\site-packages (from jupyter-server->jupyterLab-git) (1.5.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in e:\soft\anaconda\lib\site-packages (from jupyter-server->jupyterLab-git) (3.3.4)
# Requirement already satisfied: ipython-genutils in e:\soft\anaconda\lib\site-packages (from jupyter-server->jupyterLab-git) (0.2.0)
# Requirement already satisfied: prometheus-client in e:\soft\anaconda\lib\site-packages (from jupyter-server->jupyterLab-git) (0.8.0)
# Requirement already satisfied: tornado>=6.1.0 in e:\soft\anaconda\lib\site-packages (from jupyter-server->jupyterLab-git) (6.1)
# Requirement already satisfied: argon2-cffi in e:\soft\anaconda\lib\site-packages (from jupyter-server->jupyterLab-git) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in e:\soft\anaconda\lib\site-packages (from jupyter-server->jupyterLab-git) (19.0.2)
# Requirement already satisfied: jupyter-client>=6.1.1 in e:\soft\anaconda\lib\site-packages (from jupyter-server->jupyterLab-git) (6.1.7)
# Requirement already satisfied: websocket-client in e:\soft\anaconda\lib\site-packages (from jupyter-server->jupyterLab-git) (1.2.1)
# Requirement already satisfied: requests-unixsocket in e:\soft\anaconda\lib\site-packages (from jupyter-server->jupyterLab-git) (0.2.0)
# Requirement already satisfied: jinja2 in e:\soft\anaconda\lib\site-packages (from jupyter-server->jupyterLab-git) (2.11.2)
# Requirement already satisfied: traitlets>=4.2.1 in e:\soft\anaconda\lib\site-packages (from jupyter-server->jupyterLab-git) (5.0.5)
# Requirement already satisfied: terminado>=0.8.3 in e:\soft\anaconda\lib\site-packages (from jupyter-server->jupyterLab-git) (0.9.1)
# Collecting GitPython!=2.1.4,!=2.1.5,!=2.1.6
#   Using cached GitPython-3.1.24-py3-none-any.whl (180 kB)
# Requirement already satisfied: pygments in e:\soft\anaconda\lib\site-packages (from nbdime~=3.1->jupyterLab-git) (2.7.2)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: colorama in e:\soft\anaconda\lib\site-packages (from nbdime~=3.1->jupyterLab-git) (0.4.4)
# Requirement already satisfied: requests in e:\soft\anaconda\lib\site-packages (from nbdime~=3.1->jupyterLab-git) (2.24.0)
# Collecting jupyter-server-mathjax>=0.2.2
#   Using cached jupyter_server_mathjax-0.2.3-py3-none-any.whl (3.1 MB)
# Collecting ptyprocess>=0.5
#   Using cached ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in e:\soft\anaconda\lib\site-packages (from nbformat->jupyterLab-git) (3.2.0)
# Requirement already satisfied: six in e:\soft\anaconda\lib\site-packages (from packaging->jupyterLab-git) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in e:\soft\anaconda\lib\site-packages (from packaging->jupyterLab-git) (2.4.7)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in e:\soft\anaconda\lib\site-packages (from jupyter-core>=4.6.0->jupyter-server->jupyterLab-git) (227)
# Requirement already satisfied: pandocfilters>=1.4.1 in e:\soft\anaconda\lib\site-packages (from nbconvert->jupyter-server->jupyterLab-git) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in e:\soft\anaconda\lib\site-packages (from nbconvert->jupyter-server->jupyterLab-git) (0.8.4)
# Requirement already satisfied: bleach in e:\soft\anaconda\lib\site-packages (from nbconvert->jupyter-server->jupyterLab-git) (3.2.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in e:\soft\anaconda\lib\site-packages (from nbconvert->jupyter-server->jupyterLab-git) (0.5.1)
# Requirement already satisfied: entrypoints>=0.2.2 in e:\soft\anaconda\lib\site-packages (from nbconvert->jupyter-server->jupyterLab-git) (0.3)
# Requirement already satisfied: jupyterlab-pygments in e:\soft\anaconda\lib\site-packages (from nbconvert->jupyter-server->jupyterLab-git) (0.1.2)
# Requirement already satisfied: defusedxml in e:\soft\anaconda\lib\site-packages (from nbconvert->jupyter-server->jupyterLab-git) (0.6.0)
# Requirement already satisfied: testpath in e:\soft\anaconda\lib\site-packages (from nbconvert->jupyter-server->jupyterLab-git) (0.4.4)
# Requirement already satisfied: idna>=2.8 in e:\soft\anaconda\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server->jupyterLab-git) (2.10)
# Requirement already satisfied: sniffio>=1.1 in e:\soft\anaconda\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server->jupyterLab-git) (1.2.0)
# Requirement already satisfied: cffi>=1.0.0 in e:\soft\anaconda\lib\site-packages (from argon2-cffi->jupyter-server->jupyterLab-git) (1.14.3)
# Requirement already satisfied: python-dateutil>=2.1 in e:\soft\anaconda\lib\site-packages (from jupyter-client>=6.1.1->jupyter-server->jupyterLab-git) (2.8.1)
# Requirement already satisfied: urllib3>=1.8 in e:\soft\anaconda\lib\site-packages (from requests-unixsocket->jupyter-server->jupyterLab-git) (1.25.11)
# Requirement already satisfied: MarkupSafe>=0.23 in e:\soft\anaconda\lib\site-packages (from jinja2->jupyter-server->jupyterLab-git) (1.1.1)
#
# Requirement already satisfied: pywinpty>=0.5 in e:\soft\anaconda\lib\site-packages (from terminado>=0.8.3->jupyter-server->jupyterLab-git) (0.5.7)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3; python_version < "3.10" in e:\soft\anaconda\lib\site-packages (from GitPython!=2.1.4,!=2.1.5,!=2.1.6->nbdime~=3.1->jupyterLab-git) (3.7.4.3)
# Requirement already satisfied: certifi>=2017.4.17 in e:\soft\anaconda\lib\site-packages (from requests->nbdime~=3.1->jupyterLab-git) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in e:\soft\anaconda\lib\site-packages (from requests->nbdime~=3.1->jupyterLab-git) (3.0.4)
# Requirement already satisfied: setuptools in e:\soft\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyterLab-git) (50.3.1.post20201107)
# Requirement already satisfied: attrs>=17.4.0 in e:\soft\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyterLab-git) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in e:\soft\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyterLab-git) (0.17.3)
# Requirement already satisfied: webencodings in e:\soft\anaconda\lib\site-packages (from bleach->nbconvert->jupyter-server->jupyterLab-git) (0.5.1)
# Requirement already satisfied: nest-asyncio in e:\soft\anaconda\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server->jupyterLab-git) (1.4.2)
# Requirement already satisfied: async-generator in e:\soft\anaconda\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server->jupyterLab-git) (1.10)
# Requirement already satisfied: pycparser in e:\soft\anaconda\lib\site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server->jupyterLab-git) (2.20)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Installing collected packages: jupyter-server, smmap, gitdb, GitPython, jupyter-server-mathjax, nbdime, jupyterLab-git, ptyprocess
# Successfully installed GitPython-3.1.24 gitdb-4.0.9 jupyter-server-1.11.1 jupyter-server-mathjax-0.2.3 jupyterLab-git-0.33.0 nbdime-3.1.1 ptyprocess-0.7.0 smmap-5.0.0

# %%
jupyter lab build
# Out:
#   File "<ipython-input-19-14f55121cff0>", line 1
#     jupyter lab build
#             ^
# SyntaxError: invalid syntax
